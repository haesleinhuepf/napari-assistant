# %%
import napari
from napari_assistant._gui._Assistant import Assistant
from skimage.io import imread
from napari_assistant._categories import CATEGORIES

filename = 'C:/Users/ryans/OneDrive/Desktop/blobs.tif'
blobs = imread(filename)

viewer = napari.Viewer()
viewer.add_image(blobs)
assistant = Assistant(viewer)
viewer.window.add_dock_widget(assistant)
# Out:
# C:\Users\ryans\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)

# %%
assistant.load_workflow('test_only_blur.yaml')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     226             self._dump()
#     227         if self._auto_call:
# --> 228             self()
#     229
#     230     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     304         self._tqdm_depth = 0  # reset the tqdm stack count
#     305         with _function_name_pointing_to_widget(self):
# --> 306             value = self._function(*bound.args, **bound.kwargs)
#     307
#     308         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_gui\_category_widget.py in gui_function(**kwargs)
#     337             else:
#     338                 from napari_workflows._workflow import _get_layer_from_data
# --> 339                 inputs.append(_get_layer_from_data(viewer, i))
#     340
#     341         t_position = None
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in _get_layer_from_data(viewer, data)
#     416     Returns the layer in viewer that has the given data or None if such a layer doesn't exist.
#     417     """
# --> 418     for layer in viewer.layers:
#     419         if layer.data is data:
#     420             return layer
#
# AttributeError: 'NoneType' object has no attribute 'layers'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     226             self._dump()
#     227         if self._auto_call:
# --> 228             self()
#     229
#     230     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     304         self._tqdm_depth = 0  # reset the tqdm stack count
#     305         with _function_name_pointing_to_widget(self):
# --> 306             value = self._function(*bound.args, **bound.kwargs)
#     307
#     308         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_gui\_category_widget.py in gui_function(**kwargs)
#     337             else:
#     338                 from napari_workflows._workflow import _get_layer_from_data
# --> 339                 inputs.append(_get_layer_from_data(viewer, i))
#     340
#     341         t_position = None
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in _get_layer_from_data(viewer, data)
#     416     Returns the layer in viewer that has the given data or None if such a layer doesn't exist.
#     417     """
# --> 418     for layer in viewer.layers:
#     419         if layer.data is data:
#     420             return layer
#
# AttributeError: 'NoneType' object has no attribute 'layers'
# 2022-04-12 16:32:31.197 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 4.0, 4.0, 0.0)
# 2022-04-12 16:32:31.294 | DEBUG    | napari_assistant._gui._category_widget:_show_result:231 - creating new layer for id: 2550234002624
# set workflow step: Result of gaussian_blur (clesperanto)
#      args: ['blobs', 4.0, 4.0]
#    kwargs: {'destination': None, 'sigma_z': 0.0}
# signature: (source: Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage], *, destination: Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage] = None, sigma_x: float = 4.0, sigma_y: float = 4.0, sigma_z: float = 0.0) -> Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     226             self._dump()
#     227         if self._auto_call:
# --> 228             self()
#     229
#     230     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     304         self._tqdm_depth = 0  # reset the tqdm stack count
#     305         with _function_name_pointing_to_widget(self):
# --> 306             value = self._function(*bound.args, **bound.kwargs)
#     307
#     308         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_gui\_category_widget.py in gui_function(**kwargs)
#     399                 determined_kwargs = {name:value for (name,param),value in zip(signat.parameters.items(),used_args) if not bool(param.default)}
#     400
# --> 401                 manager.update(result_layer, find_function(op_name), *only_args, **determined_kwargs)
#     402                 #print("notified", result_layer.name, find_function(op_name))
#     403             except ImportError:
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in update(self, target_layer, function, *args, **kwargs)
#     268         kwargs = {k:v for k,v in kwargs.items() if not ((isinstance(v, Viewer)) or (k == 'viewer'))}
#     269
# --> 270         self.undo_redo_controller.execute(Update_workflow_step(
#     271             self.workflow,
#     272             self.viewer,
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_undo_redo_functionality.py in execute(self, action)
#      50                 copy_workflow_state(self.workflow)
#      51                 )
# ---> 52         action.execute()
#      53
#      54     def undo(self) -> Workflow:
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflowmanager_commands.py in execute(self)
#      32             args = args[:-1]
#      33         args = tuple(args)
# ---> 34         self.workflow.set(self.target_layer.name, self.function, *args, **self.kwargs)
#      35
#      36         # plus the remove zombies function
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in set(self, name, func_or_data, *args, **kwargs)
#      59         print(f'signature: {sig}')
#      60
# ---> 61         bound = sig.bind(*args, **kwargs)
#      62         bound.apply_defaults()
#      63         # Go through arguments and in case it's a callable, remove it
#
# ~\Anaconda3\envs\np_workflows_v1\lib\inspect.py in bind(self, *args, **kwargs)
#    3041         if the passed arguments can not be bound.
#    3042         """
# -> 3043         return self._bind(args, kwargs)
#    3044
#    3045     def bind_partial(self, /, *args, **kwargs):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\inspect.py in _bind(self, args, kwargs, partial)
#    2967                         # Looks like we have no parameter for this positional
#    2968                         # argument
# -> 2969                         raise TypeError(
#    2970                             'too many positional arguments') from None
#    2971
#
# TypeError: too many positional arguments
# 2022-04-12 16:32:31.547 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 4.0, 4.0, 0.0)
# 2022-04-12 16:32:31.556 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto), with id: 2550234002624
# set workflow step: Result of gaussian_blur (clesperanto)
#      args: ['blobs', 4.0, 4.0]
#    kwargs: {'destination': None, 'sigma_z': 0.0}
# signature: (source: Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage], *, destination: Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage] = None, sigma_x: float = 4.0, sigma_y: float = 4.0, sigma_z: float = 0.0) -> Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\value_widget.py in _on_value_change(self, value)
#      55         if value is self.null_value and not self._nullable:
#      56             return
# ---> 57         self.changed.emit(value)
#      58
#      59     def get_value(self):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_bases\container_widget.py in <lambda>()
#     163         """Insert widget at ``key``."""
#     164         if isinstance(widget, (ValueWidget, ContainerWidget)):
# --> 165             widget.changed.connect(lambda: self.changed.emit(self))
#     166         _widget = widget
#     167
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\psygnal\_signal.cp39-win_amd64.pyd in psygnal._signal.SignalInstance.emit()
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\events.py in _run_emit_loop(self, args)
#      84                     # TODO: add better exception handling
#      85                     if self._new_callback.get(slot):
# ---> 86                         cb(*args[:max_args])
#      87                     else:
#      88                         cb(Event(args[0], self.name, self.instance))
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in _on_change(self)
#     226             self._dump()
#     227         if self._auto_call:
# --> 228             self()
#     229
#     230     @property
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     304         self._tqdm_depth = 0  # reset the tqdm stack count
#     305         with _function_name_pointing_to_widget(self):
# --> 306             value = self._function(*bound.args, **bound.kwargs)
#     307
#     308         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_gui\_category_widget.py in gui_function(**kwargs)
#     399                 determined_kwargs = {name:value for (name,param),value in zip(signat.parameters.items(),used_args) if not bool(param.default)}
#     400
# --> 401                 manager.update(result_layer, find_function(op_name), *only_args, **determined_kwargs)
#     402                 #print("notified", result_layer.name, find_function(op_name))
#     403             except ImportError:
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in update(self, target_layer, function, *args, **kwargs)
#     268         kwargs = {k:v for k,v in kwargs.items() if not ((isinstance(v, Viewer)) or (k == 'viewer'))}
#     269
# --> 270         self.undo_redo_controller.execute(Update_workflow_step(
#     271             self.workflow,
#     272             self.viewer,
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_undo_redo_functionality.py in execute(self, action)
#      50                 copy_workflow_state(self.workflow)
#      51                 )
# ---> 52         action.execute()
#      53
#      54     def undo(self) -> Workflow:
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflowmanager_commands.py in execute(self)
#      32             args = args[:-1]
#      33         args = tuple(args)
# ---> 34         self.workflow.set(self.target_layer.name, self.function, *args, **self.kwargs)
#      35
#      36         # plus the remove zombies function
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in set(self, name, func_or_data, *args, **kwargs)
#      59         print(f'signature: {sig}')
#      60
# ---> 61         bound = sig.bind(*args, **kwargs)
#      62         bound.apply_defaults()
#      63         # Go through arguments and in case it's a callable, remove it
#
# ~\Anaconda3\envs\np_workflows_v1\lib\inspect.py in bind(self, *args, **kwargs)
#    3041         if the passed arguments can not be bound.
#    3042         """
# -> 3043         return self._bind(args, kwargs)
#    3044
#    3045     def bind_partial(self, /, *args, **kwargs):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\inspect.py in _bind(self, args, kwargs, partial)
#    2967                         # Looks like we have no parameter for this positional
#    2968                         # argument
# -> 2969                         raise TypeError(
#    2970                             'too many positional arguments') from None
#    2971
#
# TypeError: too many positional arguments
# 2022-04-12 16:32:31.596 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 4.0, 4.0, 0.0)
# 2022-04-12 16:32:31.605 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto), with id: 2550234002624
# set workflow step: Result of gaussian_blur (clesperanto)
#      args: ['blobs', 4.0, 4.0]
#    kwargs: {'destination': None, 'sigma_z': 0.0}
# signature: (source: Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage], *, destination: Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage] = None, sigma_x: float = 4.0, sigma_y: float = 4.0, sigma_z: float = 0.0) -> Union[numpy.ndarray, pyclesperanto_prototype._tier0._pycl.OCLArray, pyopencl._cl.Image, pyclesperanto_prototype._tier0._pycl._OCLImage]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17336/4030664508.py in <module>
# ----> 1 assistant.load_workflow('test_only_blur.yaml')
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_gui\_Assistant.py in load_workflow(self, filename)
#     314         self.workflow = _io_yaml_v1.load_workflow(filename)
#     315
# --> 316         initialise_root_functions(self.workflow,
#     317                                   self._viewer)
#     318         load_remaining_workflow(workflow=self.workflow,
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_workflow_io_utility.py in initialise_root_functions(workflow, viewer)
#      80
#      81         # calling the widget with the correct input images
# ---> 82         widget()
#      83
#      84 def load_remaining_workflow(workflow, viewer):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\site-packages\magicgui\widgets\_function_gui.py in __call__(self, update_widget, *args, **kwargs)
#     304         self._tqdm_depth = 0  # reset the tqdm stack count
#     305         with _function_name_pointing_to_widget(self):
# --> 306             value = self._function(*bound.args, **bound.kwargs)
#     307
#     308         self._call_count += 1
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\napari-assistant_fork\napari_assistant\_gui\_category_widget.py in gui_function(**kwargs)
#     399                 determined_kwargs = {name:value for (name,param),value in zip(signat.parameters.items(),used_args) if not bool(param.default)}
#     400
# --> 401                 manager.update(result_layer, find_function(op_name), *only_args, **determined_kwargs)
#     402                 #print("notified", result_layer.name, find_function(op_name))
#     403             except ImportError:
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in update(self, target_layer, function, *args, **kwargs)
#     268         kwargs = {k:v for k,v in kwargs.items() if not ((isinstance(v, Viewer)) or (k == 'viewer'))}
#     269
# --> 270         self.undo_redo_controller.execute(Update_workflow_step(
#     271             self.workflow,
#     272             self.viewer,
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_undo_redo_functionality.py in execute(self, action)
#      50                 copy_workflow_state(self.workflow)
#      51                 )
# ---> 52         action.execute()
#      53
#      54     def undo(self) -> Workflow:
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflowmanager_commands.py in execute(self)
#      32             args = args[:-1]
#      33         args = tuple(args)
# ---> 34         self.workflow.set(self.target_layer.name, self.function, *args, **self.kwargs)
#      35
#      36         # plus the remove zombies function
#
# c:\users\ryans\onedrive\documents\bia pol stuff\napari workflow laptop\nw fork\understanding napari workflows.docx\src\napari_workflows\_workflow.py in set(self, name, func_or_data, *args, **kwargs)
#      59         print(f'signature: {sig}')
#      60
# ---> 61         bound = sig.bind(*args, **kwargs)
#      62         bound.apply_defaults()
#      63         # Go through arguments and in case it's a callable, remove it
#
# ~\Anaconda3\envs\np_workflows_v1\lib\inspect.py in bind(self, *args, **kwargs)
#    3041         if the passed arguments can not be bound.
#    3042         """
# -> 3043         return self._bind(args, kwargs)
#    3044
#    3045     def bind_partial(self, /, *args, **kwargs):
#
# ~\Anaconda3\envs\np_workflows_v1\lib\inspect.py in _bind(self, args, kwargs, partial)
#    2967                         # Looks like we have no parameter for this positional
#    2968                         # argument
# -> 2969                         raise TypeError(
#    2970                             'too many positional arguments') from None
#    2971
#
# TypeError: too many positional arguments

# %%
from napari_workflows import WorkflowManager
manager = WorkflowManager.install(viewer)
print(manager.workflow)
# Out:
# Workflow:

# %%
from napari_assistant._categories import CATEGORIES, filter_categories, filter_operations
def op_names_in_menu(category, search_string: str = None):
    """
    Return all functions as list in a given category that contain a
    given search string.
    """
    if not hasattr(category, "tools_menu"):
        return []
    menu_name = category.tools_menu
    choices = filter_operations(menu_name)
    if search_string is not None and len(search_string) > 0:
        choices = [c for c in choices if search_string in c.lower()]
    choices = [c.split(">")[1].strip() for c in choices]
    choices = sorted(choices, key=str.casefold)
    
    return choices

op_names_in_menu(CATEGORIES["Remove noise"],'nsb')
# Out:
# ['Gaussian (scikit-image, nsbatwm)',
#  'Median (scipy, nsbatwm)',
#  'Percentile (scipy, nsbatwm)']

# %%
from napari_assistant._categories import operations_in_menu, Category
choices = list(operations_in_menu(category = CATEGORIES["Remove noise"], 
                                  search_string='nsb'))
choices
# Out:
# ['Gaussian (scikit-image, nsbatwm)',
#  'Median (scipy, nsbatwm)',
#  'Percentile (scipy, nsbatwm)']

# %%
def _get_operation_name_for_category_clicked(category: Category, search_string:str= None) -> str:
    """Create an inspect.Signature object representing a cle Category.

    The output of this function is the operation name for a clicked cataegory given a search string
    """
    # Add valid operations choices (will create the combo box)
    #from .._categories import operations_in_menu
    choices = list(operations_in_menu(category, search_string))

    default_op = category.default_op
    if not any(default_op == op for op in choices):
        #print("Default-operation is not in list!")
        default_op = None

    if default_op is None:
        return choices[0]
        
    else:
        return default_op

test = _get_operation_name_for_category_clicked(category = CATEGORIES["Remove noise"], 
                                  search_string='')
test
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [6], in <cell line: 21>()
#      18     else:
#      19         return default_op
# ---> 21 test = _get_operation_name_for_category_clicked(category = CATEGORIES["Remove noise"],
#      22                                   search_string='')
#      23 test
#
# Input In [6], in _get_operation_name_for_category_clicked(category, search_string)
#       2 """Create an inspect.Signature object representing a cle Category.
#       3
#       4 The output of this function is the operation name for a clicked cataegory given a search string
#       5 """
#       6 # Add valid operations choices (will create the combo box)
# ----> 7 from .._categories import operations_in_menu
#       8 choices = list(operations_in_menu(category, search_string))
#      10 default_op = category.default_op
#
# ImportError: attempted relative import with no known parent package

# %%
test2 = _get_operation_name_for_category_clicked(category = CATEGORIES["Remove noise"], 
                                  search_string='median')
test2
# Out:
# 2022-04-11 22:00:55.496 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-04-11 22:00:55.504 | DEBUG    | napari_assistant._gui._category_widget:_show_result:231 - creating new layer for id: 2194613105376
# 2022-04-11 22:00:55.514 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-04-11 22:00:55.522 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto), with id: 2194606972576
# opname = gaussian_blur (clesperanto)
# 2022-04-11 22:01:00.939 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 2.0, 1.0, 0.0)
# 2022-04-11 22:01:00.948 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto) [1], with id: 2194613105376
# 2022-04-11 22:01:01.134 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 3.0, 1.0, 0.0)
# 2022-04-11 22:01:01.145 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto) [1], with id: 2194613105376
# 2022-04-11 22:01:01.330 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 4.0, 1.0, 0.0)
# 2022-04-11 22:01:01.341 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto) [1], with id: 2194613105376
# 2022-04-11 22:01:02.791 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 3.0, 1.0, 0.0)
# 2022-04-11 22:01:02.801 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto) [1], with id: 2194613105376
# 2022-04-11 22:01:02.970 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 2.0, 1.0, 0.0)
# 2022-04-11 22:01:02.981 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto) [1], with id: 2194613105376
# 2022-04-11 22:01:03.158 | INFO     | napari_assistant._gui._category_widget:call_op:129 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-04-11 22:01:03.169 | DEBUG    | napari_assistant._gui._category_widget:_show_result:225 - updating existing layer: Result of gaussian_blur (clesperanto) [1], with id: 2194613105376
