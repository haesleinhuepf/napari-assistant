# %%
import napari
from napari_assistant._gui._Assistant import Assistant
from skimage.io import imread
from napari_assistant._categories import CATEGORIES
from napari_assistant._workflow_io_utility import initialise_root_functions, load_remaining_workflow
from napari_assistant._undo_redo import delete_workflow_widgets_layers
from napari_workflows import WorkflowManager

filename = 'C:/Users/ryans/OneDrive/Desktop/blobs.tif'
blobs = imread(filename)
blobs_modified = imread('C:/Users/ryans/OneDrive/Desktop/blobs_messed_up.tiff') 

viewer = napari.Viewer()
viewer.add_image(blobs_modified, name = 'not blobs')
viewer.add_image(blobs, name = 'blobs')

manager = WorkflowManager.install(viewer)
assistant = Assistant(viewer)
viewer.window.add_dock_widget(assistant)
# Out:
# C:\Users\ryans\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)

# %%
noise_widget = assistant._activate(CATEGORIES.get("Remove noise"))
# Out:
# 2022-05-09 14:05:42.704 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-05-09 14:06:17.710 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# new tasks:
#   {'Result of gaussian_blur (clesperanto)': (<function gaussian_blur at 0x0000019F7AA5D790>, 'blobs', None, 1.0, 1.0, 0.0)}
#
# undo tasks:
#  {}

# %%
assistant._activate(CATEGORIES.get("Filter"))

# %%
controller = manager.undo_redo_controller
for i in controller.undo_stack:
    print(i)
# Out:
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)

# %%
noise_widget["x"].value = 4
# Out:
# 2022-05-09 11:34:18.452 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 4.0, 1.0, 0.0)
# 2022-05-09 11:34:18.468 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)

# %%
for i in controller.undo_stack:
    print(i)
# Out:
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
noise_widget["x"].value = 8
for i in controller.undo_stack:
    print(i)
# Out:
# 2022-05-09 11:34:18.520 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 8.0, 1.0, 0.0)
# 2022-05-09 11:34:18.537 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
noise_widget["x"].value = 9
for i in controller.undo_stack:
    print(i)
# Out:
# 2022-05-09 11:34:18.585 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 9.0, 1.0, 0.0)
# 2022-05-09 11:34:18.607 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 8.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
napari.utils.nbscreenshot(viewer)

# %%
assistant.undo_action()
for i in controller.undo_stack:
    print(i)
print('CURRENT WORKFLOW:')
print(manager.workflow)
# Out:
# 2022-05-09 11:34:19.451 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 8.0, 1.0, 0.0)
# 2022-05-09 11:34:19.475 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# CURRENT WORKFLOW:
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 8.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
napari.utils.nbscreenshot(viewer)

# %%
controller.redo_stack

# %%
assistant.redo_action()
print('CURRENT WORKFLOW:')
print(manager.workflow)
# Out:
# 2022-05-09 11:34:20.420 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 9.0, 1.0, 0.0)
# 2022-05-09 11:34:20.440 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# CURRENT WORKFLOW:
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 9.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
for i in controller.undo_stack:
    print(i)
# Out:
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000001AC5D3BD700>, 'blobs', None, 8.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000001AC5D433700>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
# 2022-05-09 11:34:28.411 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 8.0, 1.0, 0.0)
# 2022-05-09 11:34:28.431 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# 2022-05-09 11:34:30.291 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 4.0, 1.0, 0.0)
# 2022-05-09 11:34:30.311 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# 2022-05-09 11:34:32.601 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-05-09 11:34:32.621 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gamma_correction (clesperanto)(..., 1.0)
# 2022-05-09 11:34:34.846 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-05-09 11:34:34.921 | INFO     | napari_assistant._gui._category_widget:call_op:171 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
