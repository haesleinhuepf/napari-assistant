# %%
import napari
from napari_assistant._gui._Assistant import Assistant
from skimage.io import imread
from napari_assistant._categories import CATEGORIES
from napari_assistant._workflow_io_utility import initialise_root_functions, load_remaining_workflow
from napari_assistant._undo_redo import delete_workflow_widgets_layers
from napari_workflows import WorkflowManager

filename = 'C:/Users/ryans/OneDrive/Desktop/blobs.tif'
blobs = imread(filename)
blobs_modified = imread('C:/Users/ryans/OneDrive/Desktop/blobs_messed_up.tiff') 

viewer = napari.Viewer()
viewer.add_image(blobs_modified, name = 'not blobs')
viewer.add_image(blobs, name = 'blobs')

manager = WorkflowManager.install(viewer)
assistant = Assistant(viewer)
viewer.window.add_dock_widget(assistant)
# Out:
# C:\Users\ryans\Anaconda3\envs\np_workflows_v1\lib\site-packages\napari_tools_menu\__init__.py:165: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)

# %%
noise_widget = assistant._activate(CATEGORIES.get("Remove noise"))
assistant._activate(CATEGORIES.get("Filter"))
# Out:
# 2022-04-27 13:34:40.924 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-04-27 13:34:41.228 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# <FunctionGui do_filter(*, input0: napari.layers.image.image.Image = <Image layer 'Result of gaussian_blur (clesperanto)' at 0x2913558c490>, op_name: str = 'gamma_correction (clesperanto)', x: float = 1.0, y: float = 1.0, z: float = 0.0, u: float = 0.0, v: float = 0.0, w: float = 0.0, a: bool = False, b: bool = False, c: bool = False, k: str = '', l: str = '', m: str = '', viewer: napari.viewer.Viewer = Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 126.5, 127.5), zoom=2.244094488188976, angles=(0.0, 0.0, 90.0), perspective=0, interactive=True), cursor=Cursor(position=(1, 1), scaled=True, size=1, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=2, ndisplay=2, last_used=0, range=((0.0, 254.0, 1.0), (0.0, 256.0, 1.0)), current_step=(127, 128), order=(0, 1), axis_labels=('0', '1')), grid=GridCanvas(stride=-1, shape=(-1, -1), enabled=False), layers=[<Image layer 'not blobs' at 0x291202f3f70>, <Image layer 'blobs' at 0x29130f28400>, <Image layer 'Result of gaussian_blur (clesperanto)' at 0x2913558c490>, <Image layer 'Result of gamma_correction (clesperanto)' at 0x29135664820>], scale_bar=ScaleBar(visible=False, colored=False, ticks=True, position=<Position.BOTTOM_RIGHT: 'bottom_right'>, font_size=10, unit=None), text_overlay=TextOverlay(visible=False, color=(0.5, 0.5, 0.5, 1.0), font_size=10, position=<TextOverlayPosition.TOP_LEFT: 'top_left'>, text=''), overlays=Overlays(interaction_box=InteractionBox(points=None, show=False, show_handle=False, show_vertices=False, selection_box_drag=None, selection_box_final=None, transform_start=<napari.utils.transforms.transforms.Affine object at 0x000002912031BE20>, transform_drag=<napari.utils.transforms.transforms.Affine object at 0x000002912031BE80>, transform_final=<napari.utils.transforms.transforms.Affine object at 0x000002912031BEE0>, transform=<napari.utils.transforms.transforms.Affine object at 0x000002912031BF40>, allow_new_selection=True, selected_vertex=None)), help='', status='Ready', tooltip=Tooltip(visible=False, text=''), theme='dark', title='napari', mouse_move_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_move at 0x000002912A2C1310>], mouse_drag_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_drag at 0x000002912A2AB790>], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x000002911E174430>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, keymap={'Shift': <function InteractionBoxMouseBindings.initialize_key_events.<locals>.hold_to_lock_aspect_ratio at 0x000002912A2ABCA0>, 'Control-Shift-R': <function InteractionBoxMouseBindings._reset_active_layer_affine at 0x0000029129F248B0>, 'Control-Shift-A': <function InteractionBoxMouseBindings._transform_active_layer at 0x0000029129F249D0>}))>

# %%
controller = manager.undo_redo_controller
for i in controller.undo_stack:
    print(i)
# Out:
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)

# %%
noise_widget["x"].value = 4
# Out:
# 2022-04-27 13:34:41.941 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 4.0, 1.0, 0.0)
# 2022-04-27 13:34:41.959 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)

# %%
for i in controller.undo_stack:
    print(i)
# Out:
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
noise_widget["x"].value = 8
for i in controller.undo_stack:
    print(i)
# Out:
# 2022-04-27 13:34:42.060 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 8.0, 1.0, 0.0)
# 2022-04-27 13:34:42.079 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
noise_widget["x"].value = 9
for i in controller.undo_stack:
    print(i)
# Out:
# 2022-04-27 13:34:42.124 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 9.0, 1.0, 0.0)
# 2022-04-27 13:34:42.142 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 8.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
napari.utils.nbscreenshot(viewer)

# %%
assistant.undo_action()
for i in controller.undo_stack:
    print(i)
print('CURRENT WORKFLOW:')
print(manager.workflow)
# Out:
# 2022-04-27 13:34:43.037 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 8.0, 1.0, 0.0)
# we are here
# 2022-04-27 13:34:43.152 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# 2022-04-27 13:34:43.231 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 8.0, 1.0, 0.0)
# 2022-04-27 13:34:43.244 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# 2022-04-27 13:34:43.277 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# CURRENT WORKFLOW:
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 8.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
napari.utils.nbscreenshot(viewer)

# %%
controller.redo_stack

# %%
assistant.redo_action()
print('CURRENT WORKFLOW:')
print(manager.workflow)
# Out:
# 2022-04-27 13:34:44.230 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 9.0, 1.0, 0.0)
# 2022-04-27 13:34:44.344 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# 2022-04-27 13:34:44.421 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gaussian_blur (clesperanto)(..., 9.0, 1.0, 0.0)
# 2022-04-27 13:34:44.436 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# 2022-04-27 13:34:44.468 | INFO     | napari_assistant._gui._category_widget:call_op:163 - gamma_correction (clesperanto)(..., 1.0)
# CURRENT WORKFLOW:
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 9.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)

# %%
for i in controller.undo_stack:
    print(i)
# Out:
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 1.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 4.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 8.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
#
# Workflow:
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 9.0, 1.0, 0.0)
#
# Workflow:
# Result of gaussian_blur (clesperanto) <- (<function gaussian_blur at 0x000002911D3DF8B0>, 'blobs', None, 9.0, 1.0, 0.0)
# Result of gamma_correction (clesperanto) <- (<function gamma_correction at 0x000002911D4518B0>, 'Result of gaussian_blur (clesperanto)', None, 1.0)
